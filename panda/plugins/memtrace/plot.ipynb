# %%
import numpy as np

with open("../../../memtrace.txt", 'r') as fid:
    hists = fid.readlines()
    
hist_k = np.zeros([64, len(hists)])
hist_u = np.zeros([64, len(hists)])

# %%
for i, hist in enumerate(hists):
    exec(hist)
    hist_k[list(K.keys()), i] = list(K.values()) 
    hist_u[list(U.keys()), i] = list(U.values())

# %%
import matplotlib.pyplot as p

start = 0
end = len(hists)
# %matplotlib inline
p.figure(figsize = (18,10))
p.imshow((hist_k-hist_u)[:, start:end],interpolation='none',cmap='bwr',origin='lower', aspect='auto', extent=[start, end, 0, 1024])
p.xlabel("Memory access")
p.ylabel("Memory address (MB)")
# Out:
# Text(0, 0.5, 'Memory address (MB)')

# %%
len(hists)
# Out:
# 2442611

# %%
hists[14000000]

# %%
hists[15000000]

# %%
len(hists)
